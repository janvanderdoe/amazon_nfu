# %%
import pandas as pd
import numpy as np
import nltk
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
import re
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from datetime import datetime

# %%
data = pd.read_csv("C:/Users/janva/Documents/Git projects/amazon_nfu/gen/output/amazon_usa_clean.csv", sep = ",")

# %%
my_stopwords = nltk.corpus.stopwords.words('english')
word_rooter = nltk.stem.snowball.PorterStemmer(ignore_stopwords=False).stem
my_punctuation = '!"$%&\'’()*+,-./:;<=>?[\\]^_`{|}~•@'

# %%
my_stopwords.append('phone')

# %%
def clean_review(review, bigrams=False):
    review = str(review)
    review = review.lower() # lower case
    review = re.sub('['+my_punctuation + ']+', ' ', review) # strip punctuation
    review = re.sub('\s+', ' ', review) #remove double spacing
    review = re.sub('([0-9]+)', '', review) # remove numbers
    review_token_list = [word for word in review.split(' ')
                            if word not in my_stopwords] # remove stopwords

    review_token_list = [word_rooter(word) if '#' not in word else word
                        for word in review_token_list] # apply word rooter
    if bigrams:
        review_token_list = review_token_list+[review_token_list[i]+'_'+review_token_list[i+1]
                                            for i in range(len(review_token_list)-1)]
    review = ' '.join(review_token_list)
    return review

# %%
data['review'] = data.review.apply(clean_review)

# %%
data = data[data['brand_overall'] == 'apple']
data
# Out:
#         Unnamed: 0 variant  Unnamed..0.1  \
# 0                1   black             0
# 2                3   black             2
# 8                9   black             8
# 9               10   black             9
# 10              11   black            10
# ...            ...     ...           ...
# 128342      128343     NaN        122004
# 128343      128344     NaN        122005
# 128476      128477     NaN         25188
# 128483      128484     NaN         25186
# 128487      128488     NaN         25187
#
#                                     asin_url    brand        model  \
# 0       https://www.amazon.com/dp/B07ZPKN6YR   Apple    IPhone 11
# 2       https://www.amazon.com/dp/B07ZPKN6YR   Apple    IPhone 11
# 8       https://www.amazon.com/dp/B07ZPKN6YR   Apple    IPhone 11
# 9       https://www.amazon.com/dp/B07ZPKN6YR   Apple    IPhone 11
# 10      https://www.amazon.com/dp/B07ZPKN6YR   Apple    IPhone 11
# ...                                      ...      ...          ...
# 128342  https://www.amazon.com/dp/B079H86JGH   Apple    MJVE2LL/A
# 128343  https://www.amazon.com/dp/B079H86JGH   Apple    MJVE2LL/A
# 128476  https://www.amazon.com/dp/B077H73WSR   Apple     IPhone 7
# 128483  https://www.amazon.com/dp/B077H73WSR   Apple     IPhone 7
# 128487  https://www.amazon.com/dp/B077H73WSR   Apple     IPhone 7
#
#                                                      link  \
# 0       https://amazon.com/Apple-iPhone-11-64GB-Black/...
# 2       https://amazon.com/Apple-iPhone-11-64GB-Black/...
# 8       https://amazon.com/Apple-iPhone-11-64GB-Black/...
# 9       https://amazon.com/Apple-iPhone-11-64GB-Black/...
# 10      https://amazon.com/Apple-iPhone-11-64GB-Black/...
# ...                                                   ...
# 128342  https://amazon.com/Apple-MacBook-MJVE2LL-13-in...
# 128343  https://amazon.com/Apple-MacBook-MJVE2LL-13-in...
# 128476  https://amazon.com/Apple-iPhone-Fully-Unlocked...
# 128483  https://amazon.com/Apple-iPhone-Fully-Unlocked...
# 128487  https://amazon.com/Apple-iPhone-Fully-Unlocked...
#
#                                             product_title                name  \
# 0       Apple iPhone 11, 64GB, Black - Unlocked (Renew...                  wp
# 2       Apple iPhone 11, 64GB, Black - Unlocked (Renew...                 Dov
# 8       Apple iPhone 11, 64GB, Black - Unlocked (Renew...  Salvatore Ferrigno
# 9       Apple iPhone 11, 64GB, Black - Unlocked (Renew...       John Franklin
# 10      Apple iPhone 11, 64GB, Black - Unlocked (Renew...       Charis Walker
# ...                                                   ...                 ...
# 128342  Apple MacBook Air MJVE2LL/A 13-inch Laptop 1.6...         Luis Pradel
# 128343  Apple MacBook Air MJVE2LL/A 13-inch Laptop 1.6...               Tilda
# 128476  Apple iPhone 7, Fully Unlocked, 128GB (Renewed...              Teresa
# 128483  Apple iPhone 7, Fully Unlocked, 128GB (Renewed...             Mark T.
# 128487  Apple iPhone 7, Fully Unlocked, 128GB (Renewed...          Larry Gary
#
#         rating  ... uniq_brand_overall uniq_parent uniq_sku_parent  \
# 0          4.0  ...           0.323818         718        0.005571
# 2          4.0  ...           0.323818         718        0.069638
# 8          5.0  ...           0.323818         718        0.019499
# 9          4.0  ...           0.323818         718        0.069638
# 10         4.0  ...           0.323818         718        0.069638
# ...        ...  ...                ...         ...             ...
# 128342     5.0  ...           0.323818       39195             NaN
# 128343     5.0  ...           0.323818       39195             NaN
# 128476     5.0  ...           0.323818       39195             NaN
# 128483     5.0  ...           0.323818       39195             NaN
# 128487     4.0  ...           0.323818       39195             NaN
#
#        uniq_variant_parent uniq_variant_brand  count_variant_parent  \
# 0                 0.813370           0.267239                     6
# 2                 0.813370           0.267239                     6
# 8                 0.813370           0.267239                     6
# 9                 0.813370           0.267239                     6
# 10                0.813370           0.267239                     6
# ...                    ...                ...                   ...
# 128342            0.083761           0.020718                    16
# 128343            0.083761           0.020718                    16
# 128476            0.083761           0.020718                    16
# 128483            0.083761           0.020718                    16
# 128487            0.083761           0.020718                    16
#
#        conspicuousness oldest_review  time_since_oldest_review  \
# 0                  1.0    2022-07-20                        38
# 2                  1.0    2022-03-30                       141
# 8                  1.0    2022-05-25                       106
# 9                  1.0    2022-03-30                       153
# 10                 1.0    2022-03-30                       164
# ...                ...           ...                       ...
# 128342             NaN    2011-12-11                      3679
# 128343             NaN    2011-12-11                      3581
# 128476             NaN    2011-12-11                      3865
# 128483             NaN    2011-12-11                      3908
# 128487             NaN    2011-12-11                      3787
#
#         median_variant_parent
# 0                     low NFU
# 2                     low NFU
# 8                     low NFU
# 9                     low NFU
# 10                    low NFU
# ...                       ...
# 128342               high NFU
# 128343               high NFU
# 128476               high NFU
# 128483               high NFU
# 128487               high NFU
#
# [41607 rows x 53 columns]

# %%
low_nfu = data[data['median_variant_parent'] == 'low NFU']
high_nfu = data[data['median_variant_parent'] == 'high NFU']

# %%
asins = [asin for asin in data['version_asin'].unique() if str(asin) != 'nan']

# %%
len(asins)
# Out:
# 472

# %%
reviews = []
i = 0
for asin in asins:
    subset = data[data['version_asin'] == asin]
    reviews_asin = {'asin' : asin}
    reviews_asin['review'] = ' '.join(subset['review'])
    reviews_asin['nfu'] = subset['median_variant_parent'].unique()[0]
    reviews.append(reviews_asin)
    print(f"{i}/{len(asins)}")
    i += 1
# Out:
# 0/472
# 1/472
# 2/472
# 3/472
# 4/472
# 5/472
# 6/472
# 7/472
# 8/472
# 9/472
# 10/472
# 11/472
# 12/472
# 13/472
# 14/472
# 15/472
# 16/472
#
# [861 rows x 3 columns]

# %%
reviews = []
i = 0
#for asin in asins:
    reviews_asin = {'asin' : asin}
    string_of_reviews = ' '.join([row['review'] for index, row in data.iterrows()
                                if str(row['version_asin']) == str(asin)])
    if string_of_reviews != '':
        reviews_asin['review'] = string_of_reviews
        reviews.append(reviews_asin)
    print(f"{i}/{len(asins)}")
    i += 1
print(len(reviews))
# Out:
# [{'asin': 'B084HM9YWW',
#   'review': 'skeptic get one renew iphon decid tri order iphon   gb black receipt  day got upon inspect expect perfect condit give  star littl hair scratch lower side realli see sinc appli screen protector see 😁 around camera len light scratch also see hardli notic batteri life mine say  bad think let see goe heavi daili user could problem peopl connect mobil account work everyth els work great camera speaker sound face recognit great buy save money new iphon would recommend ye everyon experi differ give  day return exchang  amaz came perfect condit cours scratch end expect use case bought cover matter  came like new condit satisfi  advertis excel condit even came screen protector save seller purchas futur '},
#  {'asin': 'B08H8VZ6PV',
#   'review': 'definit skeptic come pixel xl og nexu p meet need refresh updat secur protect  mom love bought gift surprisingli much faster pixel  best ever far make sure download nova launcher custom everyth want  pixel first foray back android life year appl train took get use navig manag pretti well like camera pixel especi night thing done million time iphon bag water bottl screw cap tightli enough insid bag littl wet messag use usb port dri ok fine hour later pixel told safe use port charg night usual appar fri batteri next day hold charg even turn ever think lifestyl could lead get wet stay away  well worth money flagship mean take support excel camera softwar pretti damn close  product use test function regular wash condit pixel surviv rate    disappoint unabl even see call play game even abl answer also fingerprint reader work replac w samsung relief googl hold breath  wife use  month nice display power hardwar excel camera featur less size weight  made switch samsung galaxi phone  phone previous happi great  easili activ best ever except nexu p great produc googl  model number receiv gh jp version us version ge respect g version technolog equival howev abl get network system reject imei us model learn hard way today spent h tech support seem way get onto network briefli work fresh activ sim next day need new sim disappoint  love  accept price great pic quick g versatil good tool manag lige would recommend  awesom camera great realli good camera price qualiti build great batteri life  pay almost  buck new sim tray origin fell scuff chip hous camera terribl compar renew renew dirti beat function batteri life incred great valu work great nice featur wish wireless charg  nice function great fingerprint reader fast  expect one disappoint stylu galaxi tablet work one present friend love gener good even though cheap version pixel  use better screen materi use  week without glass protector pocket key lightn bit worst thing rest lightli smooth concret surfac screen broke scratch glass side side without even fallen receiv sever blow  love beauti pictur price highli recommend  realli enjoy pure android experi last expect least last  year price point googl updat fri motherboard damag one month warranti expir engag googl support unsympathet follow advis repair option ubreakifix said fairli common problem appeal unsuccess googl extend warranti given caus problem  misl product descript promis devic accept major carrier find upon receipt item work major carrier disappoint wast time product return solid mechan hardwar standpoint ui clean intuit end bite bullet hook tmobil gotten g yet expect much g pretti suck everyon understand stand still live g world guess face recognit overal realli good though  smooth love pixel g everi day  first pixel  order g love camera user interfac batteri life seamless integr googl app stop accept text messag iphon fix chang set declar corrupt boot dupe send googl repair center deserv star review someplac els texa warranti receiv back  agon week later show charg worst custom servic experi life know high end guess similarli price phone work month without die reason realli great last thu  star give less  typic pixel qualiti like size  use everyday work camera nice  es bastant bueno obstant la cámara carec de calidad  experi may other may end bad struggl googl support respond hey googl ok googl understand command respond stop work  week purchas set good assist respond screen freez often hang time regular restart dont help googl support absolut terribl place hold support agent told know liter said said tablet support agent cant help camera great batteri life quit good certainli good way mani niggl  great phonepictur goodbatteri life also good encanta work work fairli well batteri last forev compar pixel  ton issu googl fi random network drop swap network lose servic sever restart mid call look place eat went total dead tri charg noth happen final hour turn hold power button  second call talk tech fi basic troubl ...
#  {'asin': 'B07ZPKN6YR',
#   'review': 'appl phone alway great phone  day return polici think import batteri life though best screen function pretti well also face id work great best part regular run storag start go slow appl even run storag even get icloud run slow alway love appl recommend even though much newer model told still work good keep mind though batteri life amaz find import mention first iphon  android basic happi perform processor function batteri level rate  bare qualifi seller spec real issu screen appl replac bright problem happi  got coupl day ago far issu ding seem work great good buy 👍🏻 perfect work sim card immedi connect appl id work perfect knew minor imperfect minuscul bare notic exactli need quick turn around  came screen protector  batteri readi set good buy  expect wish batteri higher  overal good buy  order excel condit lot visibl scratch  ship fast came good packag good condit visibl scratch crack batteri maximum capac  still last awhil would say well worth  like new econom came charger perfect b day present 🎁 👌 came veey fast like batteri goe quick  purchas iphon  husband comput liter often difficulti bit concern chang last one iphon  arriv time good condit set easi much easier transit expect watch youtub video figur oper without home button would never guess refurbish good new  minor scratch paid “excel condit “ fine realli love major upgrad iphon happi purchas  super bien ha dado problema excelent servicio se recibio en tiempo forma  recomendado sometim freez might tri move speed light haha packag suck doesnt feel anyth like orgin unbox appl scratch turn look brand new honestli feel like expens im complain almost brand new thing miss origin packag best money spent long time devic came excel condit defect damag deliveri super fast  honestli scare purchas onlin husband need phone took sever day make mind decid husband enjoy phone problem husband get facial recognit work big issu total fine  size bought iphon  wife love get use new featur batteri life way beyond phone  like everi thing bought  hybrid rate review hiccup order custom servic quick friendli help realli appreci got work left happi camper beauti refurbish probabl tell apart brand new one  bare  batteri life expect better imposs believ new clean look like never use beauti job use day may say someth later say extrem pleas fairli price  first littl skeptic purchas got fast rd day use box wonder batteri screen camera great post pic later  love realli recommend like brand new almost yeah   star love everyth say look preform like brand new batteri health  put straight talk sim connect immedi totallti unlock even came screen protector instal thank buyspri great great price  excel berri good bought  black came look brand new batteri capac  bad price upgrad  happi purchas  great deal first one bought amazon still disappoint buy refurbish cheaper better environ buy brand new said struggl feel bought new first tri iphon  left horribl batteri scratchi screen one hope least would  capac batteri instead  near futur probabl get new batteri start question whether worth frustrat great experi buy iphon even better upgrad  great safe way buy use phone hand lowest price even cheaper fb marketplac use face recognit fingerprint reader believ everyth work fine far day  el celular llego en excelent condicion desbloqueado con la cantidad de memoria que pedí lo unico malo es que llego con  de batería pero fuera de eso por su precio es un ganga  easi set fulli unlock perfect love replac lost xr plan iphon  pro  nice like wait  pro  scratch network compat  increíbl el producto  vida útil de la batería cámara increíbl reconocimiento facial el teléfono vino en perfecta condicion como física e interna  receiv order today happi purchas batteri health  everyth seem work intend  transfer old ip  easi extra display space nice display text imag bit improv littl ratti transform charger disapoint  everyth expect light scratch great batteri health easi set entir great authent appl devic scratch crack s ...

# %%
# the vectorizer object will be used to transform text to vector form
vectorizer = CountVectorizer(max_df=0.8, min_df=25, token_pattern='\w+|\$[\d\.]+|\S+')

# %%
def display_topics(dataset, no_top_words):
    tf = vectorizer.fit_transform(dataset['review']).toarray()

    # tf_feature_names tells us what word each column in the matric represents
    tf_feature_names = vectorizer.get_feature_names()
    
    model = LatentDirichletAllocation(n_components=number_of_topics, random_state=0)
    
    model.fit(tf)
    
    topic_dict = {}
    i = 0
    for topic_idx, topic in enumerate(model.components_):
        begin = datetime.now()
        topic_dict["Topic %d words" % (topic_idx)]= ['{}'.format(tf_feature_names[i])
                        for i in topic.argsort()[:-no_top_words - 1:-1]]
        topic_dict["Topic %d weights" % (topic_idx)]= ['{:.1f}'.format(topic[i])
                        for i in topic.argsort()[:-no_top_words - 1:-1]]
        end = datetime.now()
        print(f"{i}/{number_of_topics} in {end-begin}")
        i += 1
    return pd.DataFrame(topic_dict)

# %%
number_of_topics = 5

low_nfu_topics = display_topics(dataset = low_nfu, no_top_words = 20)

high_nfu_topics = display_topics(dataset = high_nfu, no_top_words = 20)
# Out:
# 0/5 in 0:00:00
# 1/5 in 0:00:00
# 2/5 in 0:00:00
# 3/5 in 0:00:00
# 4/5 in 0:00:00
# 0/5 in 0:00:00
# 1/5 in 0:00:00
# 2/5 in 0:00:00
# 3/5 in 0:00:00
# 4/5 in 0:00:00

# %%
for row in high_nfu['review']:
    print(len(row))
# Out:
# 17389
# 225699
# 279
# 3953
# 4946
# 997
# 1685
# 277
# 39872
# 50
# 1359
# 301
# 1567
# 173
# 5647
# 2713
# 618
# 271
# 400
# 43
# 2571
# 4303
# 125
# 3
# 5819
# 117
# 2535
# 585
# 245
# 475
# 710
# 571
# 62
# 6
# 22
# 1354
# 689
# 3375
# 82
# 103
# 13
# 33
# 77270
# 1537
# 1639
# 20851
# 3477
# 3463
# 995
# 10126
# 4780
# 601
# 2218
# 1893
# 4475
# 303
# 3666
# 456
# 5737
# 1344
# 1077
# 1202
# 46
# 4659
# 411
# 21
# 73
# 5863
# 99
# 1567
# 88
# 164
# 107
# 65
# 54712
# 21952
# 108655
# 102566
# 114720
# 9563
# 73
# 6656
# 12936
# 1839
# 9201
# 6673
# 7532
# 1483
# 8445
# 28859
# 35223
# 20455
# 1624
# 8744
# 1411
# 2087
# 313
# 7200
# 1135
# 25685
# 6626
# 467
# 757
# 460
# 205
# 3106
# 2382
# 1496
# 1924
# 263
# 476
# 2079
# 3139
# 387
# 2230
# 3230
# 1101
# 443
# 934
# 7957
# 37
# 983
# 2317
# 1449
# 259
# 675
# 1943
# 354
# 3104
# 1138
# 2136
# 92
# 194
# 51
# 371
# 1230
# 54
# 28
# 45
# 45203
# 15441
# 118189
# 66053
# 2096
# 9867
# 25145
# 15634
# 14066
# 1379
# 12748
# 3204
# 4306
# 2716
# 15562
# 19344
# 14624
# 3334
# 4063
# 9106
# 366
# 7380
# 230
# 923
# 229
# 37195
# 1216
# 3227
# 898
# 1126
# 1235
# 1544
# 1953
# 3462
# 1567
# 316
# 742
# 713
# 8327
# 5332
# 66
# 665
# 335
# 635
# 1464
# 310
# 570
# 117
# 313
# 131
# 120
# 42
# 28963
# 11235
# 9758
# 21339
# 1345
# 6319
# 2841
# 333
# 3526
# 1065
# 49
# 838
# 1035
# 577
# 288
# 1766
# 327
# 305
# 1305
# 159
# 94
# 58
# 585
# 18
# 148
# 412
# 143
# 33
# 142
# 137
# 31
# 101
# 652
# 93939
# 21243
# 2200
# 4949
# 5291
# 1186
# 275
# 2172
# 65
# 297
# 2524
# 110
# 758
# 91
# 89
# 155
# 248
# 5335
# 114
# 432
# 330
# 4037
# 520
# 1776
# 433
# 961
# 77
# 149297
# 17700
# 9422
# 34465
# 2083
# 1456
# 12683
# 12557
# 1247
# 4148
# 1212
# 7050
# 3703
# 4489
# 1554
# 2357
# 355
# 2873
# 5247
# 3865
# 575
# 5451
# 670
# 2583
# 4584
# 2648
# 1502
# 794
# 723
# 2918
# 649
# 2229
# 482
# 868
# 1103
# 1091
# 530
# 1064
# 238
# 2120
# 30
# 111
# 135
# 563
# 2000
# 4376
# 363
# 852
# 17
# 136
# 36
# 149
# 408
# 115
# 114
# 67768
# 1262
# 4275
# 12809
# 253
# 13507
# 6922
# 32963
# 13288
# 5989
# 18646
# 8516
# 10699
# 4441
# 13590
# 132
# 19343
# 14322
# 506
# 2078
# 7090
# 1963
# 369
# 2421
# 3625
# 1511
# 1362
# 415
# 192
# 344
# 4781
# 275
# 382
# 164
# 1053
# 1677
# 877
# 6434
# 368
# 6958
# 262
# 154
# 6
# 107
# 2076
# 639
# 2252
# 368
# 761
# 667
# 71
# 226
# 107
# 130
# 702
# 254
# 178
# 337
# 62
# 987
# 436
# 88
# 135
# 2
# 105
# 64
# 73
# 418
# 626
# 59
# 32646
# 122597
# 5997
# 1398
# 3386
# 4989
# 581
# 1787
# 1205
# 1306
# 7080
# 901
# 1465
# 7882
# 467
# 879
# 433
# 769
# 137
# 314
# 1942
# 1159
# 120
# 131
# 39
# 119
# 238
# 39282
# 2789
# 517
# 5635
# 1578
# 1279
# 1103
# 407
# 549
# 1025
# 199
# 423
# 413
# 42
# 221
# 428
# 321
# 189

# %%
type(low_nfu_topics)
# Out:
# pandas.core.frame.DataFrame

# %%
low_nfu_topics
# Out:
#    Topic 0 words Topic 0 weights Topic 1 words Topic 1 weights Topic 2 words  \
# 0        scratch           404.9          issu           121.9       charger
# 1          iphon           391.4         charg            92.5          appl
# 2           good           375.4       purchas            82.6           use
# 3           love           273.1           one            81.5           one
# 4          would           257.6          time            81.2       product
# 5            use           251.4           get            79.0       purchas
# 6           life           234.0          life            76.4         charg
# 7          brand           224.7           use            70.9         would
# 8        purchas           216.1           day            66.2           get
# 9        perfect           192.8          turn            64.6          good
# 10           day           181.4       problem            62.0         brand
# 11           get           173.1       product            59.2       scratch
# 12          issu           169.1        receiv            54.1        amazon
# 13       qualiti           166.6        return            53.7         renew
# 14         happi           166.3         would            53.1     refurbish
# 15        realli           164.9          love            52.3        seller
# 16           one           162.5         month            51.5        return
# 17          well           155.6         money            50.3          time
# 18        camera           151.5          good            50.0        review
# 19       everyth           150.0           tri            48.5           box
#
#    Topic 2 weights Topic 3 words Topic 3 weights Topic 4 words Topic 4 weights
# 0            439.1           use           128.8         iphon           993.8
# 1            425.9           one           106.6          good           777.2
# 2            410.5       product           103.7           use           497.3
# 3            391.3       scratch           102.4           one           484.1
# 4            360.5        amazon            97.4         would           435.0
# 5            323.1          good            84.3           get           394.8
# 6            302.9          even            69.2        seller           381.1
# 7            297.9         brand            62.3       purchas           366.7
# 8            294.1         renew            62.2          life           360.7
# 9            293.0           got            61.6         charg           359.2
# 10           272.9           day            59.0           day           356.7
# 11           265.0          issu            57.2          time           325.3
# 12           215.6          time            55.2           got           320.6
# 13           206.9         arriv            53.9        return           317.3
# 14           188.4       purchas            53.5        bought           309.6
# 15           180.4          life            51.4          appl           301.0
# 16           177.7        receiv            51.1           sim           298.5
# 17           175.5          well            50.9       problem           298.1
# 18           169.3       speaker            49.0        unlock           296.9
# 19           168.5         iphon            48.3          back           293.9

# %%
high_nfu_topics
# Out:
#    Topic 0 words Topic 0 weights Topic 1 words Topic 1 weights Topic 2 words  \
# 0           work          3157.4           new          3137.7          work
# 1          great          2232.2          came          2808.6       batteri
# 2            new          1807.9          work          2782.7           new
# 3        batteri          1694.6         great          2463.7         iphon
# 4           good          1674.3       batteri          2372.7        screen
# 5          iphon          1520.5       scratch          2368.3         great
# 6           like          1284.1        screen          2112.7          like
# 7            use          1129.5          like          1940.9       scratch
# 8           came          1041.4          good          1934.1          good
# 9           look           967.8         iphon          1688.1          came
# 10        condit           949.6          love          1627.8           use
# 11           one           942.3          look          1617.5            el
# 12       purchas           882.2           buy          1528.6           buy
# 13         would           801.8        condit          1521.7            de
# 14        screen           795.0         brand          1487.1            la
# 15           get           749.4       perfect          1311.8        condit
# 16          life           741.0       purchas          1275.7          look
# 17         charg           733.6          life          1197.5          life
# 18          issu           722.4           one          1193.6       purchas
# 19          love           706.7         would          1080.7           one
#
#    Topic 2 weights Topic 3 words Topic 3 weights Topic 4 words Topic 4 weights
# 0           1545.1         iphon           564.4       batteri          1754.0
# 1           1422.8           new           429.6          work          1693.1
# 2           1284.5          appl           372.7         iphon          1184.8
# 3           1250.2          like           335.7           new          1060.3
# 4           1072.3           use           287.3         great           914.2
# 5           1041.6        screen           230.8           use           783.7
# 6           1002.6         would           219.0          like           779.6
# 7            973.1       batteri           218.9          good           722.1
# 8            904.3           one           215.4           buy           632.3
# 9            820.6         great           211.3           get           614.4
# 10           706.6          look           197.8         would           592.1
# 11           694.4        amazon           186.7           one           587.9
# 12           693.5          work           186.7          look           579.7
# 13           673.3          good           171.1       purchas           565.2
# 14           665.3           get           160.1        seller           544.5
# 15           625.2         charg           148.6          time           512.5
# 16           612.2           buy           145.7         charg           511.2
# 17           583.2          came           143.9        return           505.8
# 18           579.9         brand           137.7           day           497.4
# 19           577.8       product           132.0        screen           491.3

# %%
high_nfu_topics.to_csv("C:/Users/janva/Documents/Git projects/amazon_nfu/gen/paper/high_nfu_by_asin_iphone_topics.csv", sep = ";")
low_nfu_topics.to_csv("C:/Users/janva/Documents/Git projects/amazon_nfu/gen/paper/low_nfu_by_asin_iphone_topics.csv", sep = ";")

# %%
data['review'][0]+data['review'][1]
# Out:
# 'skeptic get one renew iphon decid tri order iphon   gb black receipt  day got upon inspect can’t expect perfect condit that’ i’m give  star littl hair scratch lower side can’t realli see sinc appli screen protector can’t see 😁 around camera len light scratch also can’t see hardli notic batteri life mine say  bad think let’ see goe i’m heavi daili user could problem peopl connect mobil account it’ work everyth els work great camera speaker sound face recognit great buy save money new iphon would recommend ye everyone’ experi differ give  day return exchang definit skeptic come pixel xl og nexu p meet need refresh updat secur protect '
